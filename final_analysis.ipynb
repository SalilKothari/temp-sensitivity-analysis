# %%
import pandas as pd

# %%
final = pd.read_csv('all_transistors_sensitivity.csv')
final
# Out:
#                  transistor_name  Ciss_pct_change  Ciss_r2  Ciss_tempco  \
# 0               CREE_C3M0016120K              NaN      NaN          NaN
# 1               CREE_C3M0060065J              NaN      NaN          NaN
# 2               CREE_C3M0065100J              NaN      NaN          NaN
# 3               CREE_C3M0120065J              NaN      NaN          NaN
# 4               CREE_C3M0120100J              NaN      NaN          NaN
# 5              CREE_CAB530M12BM3              NaN      NaN          NaN
# 6              CREE_WAB300M12BM3              NaN      NaN          NaN
# 7          Fuji_2MBI100XAA120-50              NaN      NaN          NaN
# 8          Fuji_2MBI200XAA065-50              NaN      NaN          NaN
# 9          Fuji_2MBI200XBE120-50              NaN      NaN          NaN
# 10         Fuji_2MBI300XBE065-50              NaN      NaN          NaN
# 11         Fuji_2MBI300XBE120-50              NaN      NaN          NaN
# ...

# %% [markdown]
# large amoung of NaNs because there weren't enough measurements of these values are different temperatures (Anything less than 2 or 3 was thrown out for robustness). Another reason ins that fitting

# %%
# avg_sens = final.mean(numeric_only=True)
# std_sens = final.std(numeric_only=True)

# avg_sens.sort_values(ascending=False)
# avg_sens
# # std_sens
# Out:
# Id_switch        0.001325
# Rds_on_switch    0.004724
# Id_diode         0.000898
# Rds_on_diode     0.003945
# Ciss                  NaN
# Coss                  NaN
# Crss                  NaN
# Vth                   NaN
# gm                    NaN
# gds             -0.002035
# Id_sat           0.003557
# Vt_thermal       0.002816
# dtype: float64
